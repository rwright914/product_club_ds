# %% [markdown]
# # Red Jaguar API Process Documentation
# ## Google Search Results API : SerpAPI Wrapper
# ### Author: Rebecca Wright - 06/14/21

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>This document does not have the SerpApi key hardcoded into it.  Visit https://serpapi.com/ to create an account and receive an individualized API key.  SerpApi has a free 15-day trial membership.</strong>
# </div>

# %% [markdown]
# #### Installs

# %%
#pip install requests
#pip install google-search-results

# %% [markdown]
# <div class="alert alert-info">
#   <strong>Development Notes:</strong><br>
#     google-search-results documentation:  https://pypi.org/project/google-search-results/<br>
# serpapi google-search-results python wrapper documentation: https://github.com/serpapi/google-search-results-python
# </div>

# %% [markdown]
# #### Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Get search results using Requests (Method 1)
# Get data directly from an API using Python with the `requests` library.

# %% [raw]
# Coding Note:
#
# </> GET Request Syntax
#
# https://serpapi.com/search.json?engine=google_jobs&q=barista+new+york&hl=en&api_key= *****"<your secret api key>"******

# %%
base_url="https://serpapi.com/search?engine=google_jobs"

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>API KEY needed to move forward:</strong><br>
#     The next block of code WILL NOT EXECUTE unless the code is updated to include a valid SerpAPI key.  An API key is free for a 15-day trial period and can be obtained by visiting <strong>https://serpapi.com/</strong>
# </div>

# %%
req = requests.get(
    base_url,
    params = {
      "engine": "google_jobs",
      "q": "barista new york",
      "hl": "en",
      "api_key": "<your secret api key>"
    }
)

# %%
req
# Out:
# <Response [401]>

# %%
data = req.json()
data
# Out:
# {'error': 'Invalid API key. Your API key should be here: https://serpapi.com/manage-api-key'}

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['search_metadata', 'search_parameters', 'jobs_results', 'chips'])

# %%
len(data['jobs_results'])
# Out:
# 10

# %%
data['jobs_results'][0].keys()
# Out:
# dict_keys(['title', 'company_name', 'location', 'via', 'description', 'thumbnail', 'extensions', 'detected_extensions', 'job_id'])

# %%
data['chips']
# Out:
# [{'type': 'Title',
#   'param': 'job_family_1',
#   'options': [{'text': ".WGYX8{box-sizing:border-box;background:#fff;border:1px solid #dadce0;border-radius:18px;color:#3c4043;cursor:pointer;display:inline-block;font:400 12px Roboto,arial,sans-serif;height:36px;min-width:36px;position:relative}.WGYX8:after{bottom:-7px;content:'';left:-1px;position:absolute;right:-1px;top:-7px}.WGYX8:hover{background:#f8f9fa}.KymMLe:focus .WGYX8,a:focus .WGYX8,.WGYX8:focus{background:#f8f9fa;border-color:#9aa0a6;color:#e8eaed}.KymMLe:focus .WGYX8:hover:not(:active),a:focus .WGYX8:hover:not(:active),.WGYX8:hover:focus:not(:active){background:#dadce0;border-color:#9aa0a6}.WGYX8:hover,.KymMLe:focus .WGYX8,a:focus .WGYX8,.KymMLe:active .WGYX8,a:active .WGYX8,.WGYX8:focus,.WGYX8:active{color:#202124}.KymMLe:active .WGYX8:not([disabled]),a:active .WGYX8:not([disabled]),.WGYX8:active:not([disabled]){box-shadow:0 1px 2px rgba(60,64,67,.3), 0 2px 6px 2px rgba(60,64,67,.15);border-color:transparent;background:#fff}.WGYX8[disabled]{background:#f1f3f4;border-color:#f1f3f4;color:#bdc1c6;opacity:0.38}.WGYX8[selected]{background:#e8f0fe;border-color:#d2e3fc;color:#1967d2}.zAoYTe .WGYX8[selected]:not(:focus),html:not(.zAoYTe) .WGYX8[selected]{outline:1px solid transparent}.KymMLe:focus .WGYX8[selected],a:focus .WGYX8[selected],.WGYX8[selected]:focus{border-color:#8ab4f8;color:#174ea6;background:#d2e3fc}.KymMLe:active .WGYX8[selected],a:active .WGYX8[selected],.WGYX8[selected]:active{box-shadow:0 1px 2px rgba(66,133,244,.3), 0 1px 3px 1px rgba(66,133,244,.15);background:#e8f0fe;color:#174ea6}.WGYX8[selected]:hover{background:#d2e3fc;border-color:#d2e3fc;color:#174ea6}.KymMLe:focus .WGYX8[selected]:hover:not(:active),a:focus .WGYX8[selected]:hover:not(:active),.WGYX8[selected]:hover:focus:not(:active){background:#aecbfa;border-color:#d2e3fc}.AB4Jjf{font-size:14px;line-height:34px;padding:0 8px;text-align:center}.AB4Jjf,.qfpP8d,.ktgKbb{box-sizing:border-box;display:inline-block;height:34px;vertical-align:bottom}.AB4Jjf.gLDgs{min-width:46px;padding:0 11px}All",
#     'value': None},
#    {'text': 'Barista', 'value': 'barista'},
#    {'text': 'Starbucks barista', 'value': 'starbucks barista'},
#    {'text': 'Person', 'value': 'person'},
#    {'text': 'Certification', 'value': 'certification'},
#    {'text': 'Cook', 'value': 'cook'},
#    {'text': 'Counter person', 'value': 'counter person'},
#    {'text': 'Server', 'value': 'server'},
#    {'text': 'Team member', 'value': 'team member'}]},
#  {'type': 'Location',
#   'param': 'city',
#   'options': [{'text': 'All', 'value': None},
#    {'text': 'New York, NY', 'value': 'Owg_06VPwoli_nfhBo8LyA=='},
#    {'text': 'Long Beach, NY', 'value': 'yYQBQ_ZvwoljkDvjoW2T0w=='},
#    {'text': 'Bronxville, NY', 'value': 'J0ZDIKWSwolhVb6ehTpKYw=='},
#    {'text': 'Garden City, NY', 'value': 'xUU-IzV9womZ1QVzSHrgDg=='},
#    {'text': 'Nanuet, NY', 'value': 'MW8r0BLowonO5FzJCKUB8w=='},
#    {'text': 'Rye, NY', 'value': 'qc-LP9GQwomQZ14eXOixnA=='},
#    {'text': 'Tuckahoe, NY', 'value': 'VdAwOcGSwom67D0TQXMtEw=='},
#    {'text': 'West Nyack, NY', 'value': 'vzIgVzbowom-MeUdAm6dcg=='},
#    {'text': 'Albertson, NY', 'value': 'N0plyt6HwomvQ0G_LAGswQ=='},
#    {'text': 'Ardsley, NY', 'value': 'X2YBWKqUwomdFLoW-xr0ig=='},
#    {'text': 'Armonk, NY', 'value': 'd6-xgGi8wokXuqQOjd3JFA=='},
#    {'text': 'Atlantic Beach, NY', 'value': 'nwsRyERvwom0mXSy5emX1A=='},
#    {'text': 'Bellerose, NY', 'value': 'DSoty0ZiwolrGWosVK7UOg=='},
#    {'text': 'Greenvale, NY', 'value': 'J6FzXROGwokKTVapLXZvgg=='},
#    {'text': 'Hartsdale, NY', 'value': 'xbmw1pCUwokKnBrb6mt0qA=='},
#    {'text': 'Hastings-on-Hudson, NY', 'value': 'c_9lkenswonDC3-VRD5oKQ=='},
#    {'text': 'Hicksville, NY', 'value': 'u3lvHeKAwomU2kg0LrOA5A=='},
#    {'text': 'Irvington, NY', 'value': 'xSxJ-jzrwonVOP6gaEDiHw=='},
#    {'text': 'Lawrence, NY', 'value': 'iYi_UY5lwonoDyc2yCtcQA=='},
#    {'text': 'New City, NY', 'value': 'FZyVPQDDwonwIFXZcYIVBw=='},
#    {'text': 'New Hyde Park, NY', 'value': 'OfwQ1pJiwolAhmseIHElsA=='},
#    {'text': 'Uniondale, NY', 'value': 'L5EGUrB9wokJzAopkN4Dwg=='},
#    {'text': 'White Plains, NY', 'value': '2TWj4iKUwols_FsaEAQUVA=='},
#    {'text': 'Williston Park, NY', 'value': 'aTcdY-SHwokPI6VFey0www=='},
#    {'text': 'Yonkers, NY', 'value': 'oa9DCQjAwomi2tikhHOWvg=='},
#    {'text': 'ARDSLEY HDSN, NY', 'value': 'AAAAAAAAAAAAAAAAAAAAAA=='},
#    {'text': 'Arden, NY', 'value': 'a51WM8HZwokIIHM3zRpf0w=='},
#    {'text': 'Baldwin, NY', 'value': 'mZxjZIR7wom_Zon5y5xiFw=='},
#    {'text': 'Bellmore, NY', 'value': 'Ax4VKCl5wonSgDT3GxnAHA=='},
#    {'text': 'Berkeley Heights, NJ', 'value': 'j1YfgL26w4miHFQ6F1eRKQ=='},
#    {'text': 'Carle Place, NY', 'value': 'hXEFTYOHwolc8QmCc_WerA=='},
#    {'text': 'Cedarhurst, NY', 'value': 'hRc328ZlwonhXsREt2MLYQ=='},
#    {'text': 'Clifton, NJ', 'value': '6drDvuL-wolTMn8iM1gZZA=='},
#    {'text': 'Closter, NJ', 'value': '83-F_TzuwolwAArRIA3YWw=='},
#    {'text': 'Dobbs Ferry, NY', 'value': '20Y_Ip7swom9uR3rK9UaEA=='},
#    {'text': 'East Meadow, NY', 'value': 'xRyHMgh-wokSKBTPpQZ8aw=='},
#    {'text': 'East Norwich, NY', 'value': 'fW1W8qCDwon7X7UAPULOAg=='},
#    {'text': 'Eastchester, NY', 'value': '1YOoSOWSwolAv4tUJPbePA=='},
#    {'text': 'Edgewater, NJ', 'value': 'k4UqK072wontnGQgQuMoTw=='},
#    {'text': 'Edison, NJ', 'value': 'maG-aH_Tw4nq1INvpsUr8g=='},
#    {'text': 'Elmont, NY', 'value': 'ReHg1QRjwolxNPZXDROsDA=='},
#    {'text': 'Elmsford, NY', 'value': 'G9RGDxmVwoktOUKJXYAJXQ=='},
#    {'text': 'Englewood Cliffs, NJ', 'value': 'Fw0eHkPxwon8GIPyu8YylA=='},
#    {'text': 'Englewood, NJ', 'value': 'jXk9hxjxwom-mx-eaJrGxA=='},
#    {'text': 'Farmingdale, NY', 'value': 'HzVsCLwq6Il7xE8IEuknFQ=='},
#    {'text': 'Franklin Square, NY', 'value': 'IYqh5iFjwongahMn5I4GMg=='},
#    {'text': 'Freeport, NY', 'value': '1esxKIZ7wokVOR48olu3hQ=='},
#    {'text': 'Glen Cove, NY', 'value': 'z_V_bxGFwon84T6o2QYuTQ=='},
#    {'text': 'Glen Head, NY', 'value': 'GaCjboqDwomNuf-bbdG6mA=='},
#    {'text': 'Glenwood Landing, NY', 'value': 'S4pChOOFwolZRZdOvLiROQ=='},
#    {'text': 'Great Neck, NY', 'value': 'XQNBzXCJwom4QdhfOY3vcQ=='},
#    {'text': 'Greenwood Lake, NY', 'value': 'P-EStUchw4lCrGkjgfVqUw=='},
#    {'text': 'Harrison, NY', 'value': 'RXu0a-mWwomMlCbJwnxsVA=='}]},
#  {'type': 'Date posted',
#   'param': 'date_posted',
#   'options': [{'text': 'All', 'value': None},
#    {'text': 'Past day', 'value': 'today'},
#    {'text': 'Past 3 days', 'value': '3days'},
#    {'text': 'Past week', 'value': 'week'},
#    {'text': 'Past month', 'value': 'month'}]},
#  {'type': 'Requirements.pXCzbb{border-left:6px solid transparent;border-right:6px solid transparent;height:0;width:0}.f5QV0d{border-bottom:6px solid #1a73e8;margin-top:-41px}.X1JR3{border-top:6px solid #1a73e8}.fggD7{margin-left:27px}.ifeRGc{right:16px;position:absolute}.mrGaL{left:16px;position:absolute}.xIBC4e{background-color:#1a73e8;border-radius:8px;color:#fff;display:inline-block;font:14px Roboto-medium,arial,sans-serif-medium,sans-serif;line-height:20px;padding:8px 12px}.XBFdTb{position:absolute;z-index:80}.SPJsgc{margin-left:184px;margin-right:8px;margin-top:52px;-webkit-transition:opacity 500ms}.otfdK{right:15px;top:47px;-webkit-transition:opacity 500ms}.jxqSg{right:15px;top:-44px;-webkit-transition:opacity 500ms}.OZzQ9b{left:-16px;top:14px;-webkit-transition:opacity 500ms}New! Find jobs based on education or experience requirements',
#   'param': 'requirements',
#   'options': [{'text': 'All', 'value': None},
#    {'text': 'No degree', 'value': 'no_degree'},
#    {'text': 'No experience', 'value': 'no_experience'},
#    {'text': 'Under 3 years of experience', 'value': 'years3under'},
#    {'text': '3+ years of experience', 'value': 'years3plus'}]},
#  {'type': 'Type',
#   'param': 'employment_type',
#   'options': [{'text': 'All', 'value': None},
#    {'text': 'Full-time', 'value': 'FULLTIME'},
#    {'text': 'Part-time', 'value': 'PARTTIME'},
#    {'text': 'Contractor', 'value': 'CONTRACTOR'},
#    {'text': 'Internship', 'value': 'INTERN'}]},
#  {'type': 'Company type',
#   'param': 'industry.id',
#   'options': [{'text': 'All', 'value': None},
#    {'text': 'Foods & Beverages', 'value': '/business/naics2007/311'},
#    {'text': 'Restaurant', 'value': '/business/naics2007/722'},
#    {'text': 'Retail', 'value': '/business/naics2007/44'},
#    {'text': 'Accommodation', 'value': '/business/naics2007/721'},
#    {'text': 'Textiles & Apparel', 'value': '/business/naics2007/313'},
#    {'text': 'Engineering Services', 'value': '/business/naics2007/5413'},
#    {'text': 'Health Care', 'value': '/business/naics2007/62'},
#    {'text': 'Manufacturing', 'value': '/business/naics2007/31'},
#    {'text': 'Real Estate', 'value': '/business/naics2007/53'},
#    {'text': 'Toiletries', 'value': '/business/naics2007/3256'}]},
#  {'type': 'Employer',
#   'param': 'organization_mid',
#   'options': [{'text': 'All', 'value': None},
#    {'text': 'Starbucks', 'value': '/m/018c_r'},
#    {'text': 'HMSHost', 'value': '/m/07b72m'},
#    {'text': 'Flex by Jitjatjo', 'value': '/g/11c73vhkp1'},
#    {'text': "Macy's", 'value': '/m/01pkxd'},
#    {'text': 'The Cheesecake Factory', 'value': '/m/04n2g7'},
#    {'text': 'Bluestone Lane', 'value': '/g/11h6ys2kng'},
#    {'text': 'Barnes & Noble', 'value': '/m/01b7dt'},
#    {'text': 'Aramark', 'value': '/m/02twx1'},
#    {'text': 'Blue Bottle Coffee', 'value': '/m/03p12qd'},
#    {'text': 'Compass Group', 'value': '/g/11ckkxnnp3'},
#    {'text': 'Compass Group, North America', 'value': '/g/11bc6ld96b'},
#    {'text': 'Ralph Lauren', 'value': '/m/04lg33'},
#    {'text': 'Restaurant Associates', 'value': '/g/11dxq2tnnv'},
#    {'text': 'Cafe Grumpy', 'value': '/g/11b7c7x35l'},
#    {'text': 'Chartwells Higher Education', 'value': '/g/11g7z03l8v'},
#    {'text': 'Dartcor Food Services', 'value': '/g/11dxpj2k6d'},
#    {'text': 'Davidson Hotels and Resorts', 'value': '/g/11c73k8cmf'},
#    {'text': 'Delaware North', 'value': '/m/04xvsq'},
#    {'text': 'Dr Smood Group', 'value': '/g/11dxpvcs3m'},
#    {'text': 'Elior North America', 'value': '/g/11fy1vg90w'},
#    {'text': 'Highgate Hotels', 'value': '/g/11k6tcl93y'},
#    {'text': "Hudson's Bay Company", 'value': '/m/03gqj'},
#    {'text': 'Irving Farm Coffee Roasters', 'value': '/g/11b7crh48x'},
#    {'text': 'Joe Coffee Company', 'value': '/g/11b7cfjgxv'},
#    {'text': 'Juice Press', 'value': '/g/11cs465sqc'}]}]

# %% [markdown]
# #### Job Results in a DataFrame

# %%
pd.DataFrame(data['jobs_results'])
# Out:
#                                           title                 company_name  \
# 0                                       Barista           Blue Bottle Coffee
# 1                                       Barista  Irving Farm Coffee Roasters
# 2                                       Barista                    NeueHouse
# 3  East One Coffee Roasters is Hiring Baristas!     East One Coffee Roasters
# 4                                       Barista                    Friedmans
# 5                                       Barista              Company Culture
# 6                                       Barista           Solid State Coffee
# 7                                       Barista                    Starbucks
# 8                                       Barista                 La Bergamote
# 9                                       Barista                           RH
#
#                   location                       via  \
# 0             New York, NY          via ZipRecruiter
# 1  New York, NY (+1 other)       via Good Food Jobs.
# 2  New York, NY (+1 other)       via Culinary Agents
# 3  Brooklyn, NY (+1 other)  via New York Coffee Jobs
# 4  New York, NY (+1 other)              via Seasoned
# 5  New York, NY (+1 other)       via Culinary Agents
# 6  New York, NY (+1 other)       via Good Food Jobs.
# 7             New York, NY              via Snagajob
# 8  New York, NY (+1 other)          via ZipRecruiter
# 9             New York, NY              via LinkedIn
#
#                                          description  \
# 0  Blue Bottle Coffee is a passionate and growing...
# 1  JOB DESCRIPTION\n\nBaristas are responsible fo...
# 2  NeueHouse\n\nNeueHouse is the private workspac...
# 3  About us: East One Coffee Roasters is a coffee...
# 4  As the barista, you will skillfully craft the ...
# 5  Located between Grand Central Terminal and Bry...
# 6  As we slowly creep out of the darkness of the ...
# 7  Job Description\n\nBENEFITS\n\nBenefits-eligib...
# 8  Job Description\n\nThe candidates will need ex...
# 9  Job Description\n\nRH at its core is about tas...
#
#                                            thumbnail  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3                                                NaN
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5                                                NaN
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8                                                NaN
# 9  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                           extensions  \
# 0  [Over 1 month ago, Full-time, No degree mentio...
# 1                           [21 days ago, Part-time]
# 2  [6 days ago, 18 an hour, Full-time, No degree ...
# 3      [25 days ago, Full-time, No degree mentioned]
# 4      [16 days ago, Full-time, No degree mentioned]
# 5                            [7 days ago, Full-time]
# 6  [Over 1 month ago, Full-time, No degree mentio...
# 7                           [10 days ago, Full-time]
# 8                      [Over 1 month ago, Part-time]
# 9     [10 hours ago, Part-time, No degree mentioned]
#
#                                  detected_extensions  \
# 0  {'posted_at': 'Over 1 month ago', 'schedule_ty...
# 1  {'posted_at': '21 days ago', 'schedule_type': ...
# 2  {'posted_at': '6 days ago', 'schedule_type': '...
# 3  {'posted_at': '25 days ago', 'schedule_type': ...
# 4  {'posted_at': '16 days ago', 'schedule_type': ...
# 5  {'posted_at': '7 days ago', 'schedule_type': '...
# 6  {'posted_at': 'Over 1 month ago', 'schedule_ty...
# 7  {'posted_at': '10 days ago', 'schedule_type': ...
# 8  {'posted_at': 'Over 1 month ago', 'schedule_ty...
# 9  {'posted_at': '10 hours ago', 'schedule_type':...
#
#                                               job_id
# 0  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 1  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 2  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 3  eyJqb2JfdGl0bGUiOiJFYXN0IE9uZSBDb2ZmZWUgUm9hc3...
# 4  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 5  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 6  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 7  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 8  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 9  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...

# %% [markdown]
# ## Get search results using API Wrapper (Method 2)
# Use the SerpApi Python Wrapper for easier access.

# %% [markdown]
# Developer Notes:
#
# SerpApi developer playground can be found at https://serpapi.com/playground
#
# I played around with the "chips" parameter when trying to tailor search parameters to focus on NYC.

# %% [markdown]
# #### SerpApi query syntax - example 1

# %%
# from serpapi import GoogleSearch

# params = {
#   "engine": "google_jobs",
#   "q": "barista new york",
#   "hl": "en",
#   "api_key": "<your secret api key>"
# }

# search = GoogleSearch(params)
# results = search.get_dict()
# jobs_results = results['jobs_results']

# %% [markdown]
# #### SerpApi query syntax - example 2

# %%
# from serpapi import GoogleSearch

# search = GoogleSearch({
#     "q": "coffee", 
#     "location": "Austin,Texas",
#     "api_key": "<your secret api key>"
#   })
# result = search.get_dict()

# %% [markdown]
# #### Structuring SerpApi query results as a Python Object - example 3

# %%
# from serpapi import GoogleSearch
# search = GoogleSearch({"q": "Coffee", "location": "Austin,Texas"})
# r = search.get_object()
# assert type(r.organic_results), list
# assert r.organic_results[0].title
# assert r.search_metadata.id
# assert r.search_metadata.google_url
# assert r.search_parameters.q, "Coffee"
# assert r.search_parameters.engine, "google"

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>API KEY needed to move forward:</strong><br>
#     The next block of code WILL NOT EXECUTE unless the code is updated to include a valid SerpAPI key.
# </div>

# %%
from serpapi import GoogleSearch

# variable q is query parameter key words

params = {
  "engine": "google_jobs",
  "q": "barista new york",
  "hl": "en",
  "api_key": "<your secret api key>"
}

# %%
search = GoogleSearch(params)
search

# %%
results = search.get_dict()
results
# Out:
# {'search_metadata': {'id': '60c7cb90ca968fcda38f43a2',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/dab88e0c3b9fc833/60c7cb90ca968fcda38f43a2.json',
#   'created_at': '2021-06-14 21:35:12 UTC',
#   'processed_at': '2021-06-14 21:35:12 UTC',
#   'google_jobs_url': 'https://www.google.com/search?q=barista+new+york&ibp=htl;jobs&hl=en',
#   'raw_html_file': 'https://serpapi.com/searches/dab88e0c3b9fc833/60c7cb90ca968fcda38f43a2.html',
#   'total_time_taken': 2.87},
#  'search_parameters': {'q': 'barista new york',
#   'engine': 'google_jobs',
#   'google_domain': 'google.com',
#   'hl': 'en'},
#  'jobs_results': [{'title': 'Barista',
#    'company_name': 'Blue Bottle Coffee',
#    'location': 'New York, NY',
#    'via': 'via ZipRecruiter',
#    'description': 'Blue Bottle Coffee is a passionate and growing team of hundreds around the world, united by the simple purpose of connecting the world to delicious coffee. We roast on four coasts, make delicious drinks, clean up after ourselves, bake cookies, get change at the bank, and say please and thank you. We\'re an impossibly eclectic group of coffee experts, artists, writers, sensory scientists, bakers, designers, and all-around dreamers, who also happen to be some of the most hard-working and talented in the business. Join us.\n\nWe\'re looking for unabashed coffee and food lovers to join our crew at our cafes. The ideal barista is someone who is passionate about coffee, food and creating incredible guest experiences grounded in respect, empathy, and recognition. Don\'t have prior coffee, food or service experience? Don\'t sweat it; though that helps, it\'s not all we\'re looking for. We\'re more interested in who you are and what you care about. The whole "what" and "how" thing comes later, and with... plenty of practice.\n\nThis is a career opportunity, nonseasonal role.\nYou will:\n• Deliver impeccable hospitality to our guests and your fellow teammates\n• Work in a team to \'dial in\' and serve a selection of delicious coffees in a variety of different brewing methods including but not limited to: espresso, pour over, and cold brew\n• Expedite and serve delicious sweet and savory food created by our talented culinary team - this can include assembly, delivery and clearing of these treats\n• Stay knowledgeable about Blue Bottle\'s current coffee and food offerings through tastings, cuppings and information provided to you by your Lead Barista, Cafe Leader, the Training and Culinary Departments, and others at Blue Bottle\n• Drink your and others\' coffee and espresso drinks regularly at Blue Bottle cafes to ensure quality, uphold our standards, and keep developing your coffee palate\n• Support your team in keeping the cafe running smoothly and beautifully - these tasks may vary but can include washing dishes, clearing dishes, sweeping, dusting, mopping, cleaning and organizing condiment station, and taking out trash\n\nYou are:\n• Searching for at least 1 year of employment and a nonseasonal opportunity\n• Passionate about coffee, food and creating hospitality experiences\n• A professional - you are serious about your work but don\'t take yourself too seriously\n• Reliable and consistent - your manager and teammates can always depend on you to be punctual, looking sharp in accordance with our dress code, and bringing your A game\n• Obsessed with the details! You love honing your craft and understand each cup of coffee and each plate of delicious food for its individual potential\n• Dedicated to your team and your guests - you understand and value empathy and use it to guide interactions on and off the job\n• Eligible to work in the United States and 18 years of age or older\n\nYou have:\n• Existing Food Handler\'s Certification or certification within 30 days post-hire for the state you will be working in\n• Basic math and computer skills\n• A flexible schedule and are available to work weekends\n\nOur barista position is a dynamic one! Below we\'ve mapped out the physical demands that are essential to the role:\n• Ability to stand and walk for long periods of time. You\'re on your feet the majority of the day, whether you are standing behind bar pulling shots or walking the cafe floor\n• Use of hands to reach, grip, turn and perform precision work. You\'re using your hands to operate beautiful espresso machines, pour delicious pour overs, and operate the register (among other responsibilities)\n• As needed squat, bend, twist and reach for items below waist level or above shoulders. For example, you may have to bend down or reach up to grab cups, lids and towels\n• Ability to lift, push/pull, carry and/or move up to 50 pounds. For example, you\'ll be handling bags of coffee beans, coffee kegs, crates of milk, tub ...
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR5tE_D3p4jQG3SyoJL5ZqU1UJXO5WkNdfV0Bxd&s=0',
#    'extensions': ['Over 1 month ago', 'Full-time', 'No degree mentioned'],
#    'detected_extensions': {'posted_at': 'Over 1 month ago',
#     'schedule_type': 'Full-time'},
#    'job_id': '...'},
#   {'title': 'Barista',
#    'company_name': 'Irving Farm Coffee Roasters',
#    'location': 'New York, NY (+1 other)',
#    'via': 'via Good Food Jobs.',
#    'description': 'JOB DESCRIPTION\n\nBaristas are responsible for running the bar to Irving Farm New York standards and delivering outstanding customer service. Our baristas will develop a thorough knowledge of our coffees and maintain quality in all offerings. Irving Farm is an Equal Employment Opportunity Employer. We strongly encourage applicants of all races, ethnicities, genders, and sexual orientations to apply; we are committed to a diverse workplace and world.\n\nREQUIREMENTS\n• Candidates must have open availability and a willingness to work irregular hours, including nights and weekends\n• At least 12 months experience as barista preferred, preferably at a high volume café\n• Outstanding customer service skills\n• Preference will be given to those with a NYS Food Handler’s license; obtaining a license within 30 days of hire will be a requirement of the position\n• Ability to work with others\n• Detail oriented\n• Ability to lift, push and pull up to 50 lbs\n• Must be able to stand for long periods of... time\n\nGENERAL RESPONSIBILITIES:\n• Practice proper cleaning and preventative maintenance for espresso and brewing equipment\n• Be knowledgeable about new coffee offerings and participate in tastings of new coffees\n• Follow Irving Farm standards for opening and closing procedures\n• Uphold and maintain the standards of Irving Farm New York\n• Make drinks in a consistent manner\n• Provide service in a fun, friendly and efficient way\n• Maintain a clean and functioning bar\n• Happily assist staff from other departments when requested and where able\n• Stay informed and educated on industry trends and developments\n• Register and Customer Service\n\nBENEFITS:\n• Competitive hourly pay rate\n• Opportunities to participate in company health insurance after 90 days of employment at 50% employer contribution\n• Opportunity to participate in company 401K plan after 1 year of employment with 4% employer matching\n• Professional Development and Opportunities',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2ZVmDQTo1D2HsXvtAxXU6ryzlddm_K_SZb7qE&s=0',
#    'extensions': ['21 days ago', 'Part-time'],
#    'detected_extensions': {'posted_at': '21 days ago',
#     'schedule_type': 'Part-time'},
#    'job_id': '...'},
#   {'title': 'Barista',
#    'company_name': 'NeueHouse',
#    'location': 'New York, NY (+1 other)',
#    'via': 'via Culinary Agents',
#    'description': "NeueHouse\n\nNeueHouse is the private workspace and cultural home for creators, innovators, and thought leaders. With iconic buildings, timeless design, thought-provoking cultural experiences, and elevated hospitality, NeueHouse has reimagined the ideal environment for creative potential and progress.\n\nOur Properties\n\nNeueHouse currently operates across three different, but equally iconic properties in New York City and Los Angeles:\n• Our Madison Square (MSQ) House is situated in New York’s iconic Flatiron District, was previously home for Tepper Galleries, a well-known Manhattan auction house for international artists and collectors in the 1930s – and neighbors the 69th Regiment Armory where the first International Exhibition of Modern Art was held.\n• Our Hollywood House (HWD), which sits on Sunset Boulevard, is one of LA’s most celebrated buildings and occupies the original CBS Studio (the world’s first structure built intentionally for broadcast). Here genre-defining artists from... Orson Wells and Lucille Ball, to Janis Joplin, the Beach Boys, and Bob Dylan built their legacy.\n• Our Bradbury House (BB) sits within the Bradbury building in DTLA. Built-in 1893, the Bradbury Building is an architectural masterpiece and one of Los Angeles’ most historic landmarks. It has been heralded as one of the most thrilling spaces in all North America and is renowned for its breathtaking skylit atrium filled with walkways, stairs, balconies, and intricate ironwork.\n\nThese properties are complemented by forthcoming houses in Venice Beach, and Miami, as well as proposed European locations. Regardless of locale, and by deliberate design, all our environment and teams support, nurture and connect the NeueHouse community in reaching their creative potential.\n\nThe Role\n\nOur Food & Beverage team is a critical part of creating an outstanding NeueHouse experience and are tasked with sharing the NeueHouse food and drink philosophy with Members and Guests, alike. Baristas on our team create innovative and outstanding food and beverage journeys using our bespoke coffee, drink, and cocktail menus.\n\nBaristas represent NeueHouse in providing hospitality, warmth, and grace with all interactions, supporting, and adding to NeueHouse’s collaborative atmosphere, and making the most of every opportunity to enhance Member and Guest experience. NeueHouse’s team is lean and operates with a mindset of “no task is too small.”\n\nResponsibilities & Requirements\n\nSolution-oriented and taking pride in delivering with details in mind, Baristas build, deliver, and steward the everyday F&B moments defining NeueHouse for Members, Guests, and team. The role requires someone who is ready to:\n• Consistently provide thoughtful and personal service with the goal to develop a rapport with members and guests.\n• Ensure the Café counter and floor are set and ready for service.\n• Maintain the cleanliness and always restock equipment of the Café counter and floor.\n• Maintain thorough working knowledge of menus and be able to articulate to guests in an engaged and thoughtful manner.\n• Proficient use of POS for ordering and billing purposes.\n• Execution of the order of service in a timely and accurate manner with the goal of creating memorable service - we want Members and Guests to remember that cup of coffee!\n• Prepare all food and beverages to the standards of NeueHouse and our partners.\n• Thorough working knowledge of all beverages: coffee/tea/non-alcoholic/wines/beers/spirits.\n• Communicating with prep kitchen to ensure areas are always fully stocked with food and beverage items, alerting the kitchen when running low on a particular item.\n• Develop and coordinate the organization of various areas of The Café and other F&B outlets on property.\n• Competency in conversing with members, guests, and potential members regarding NeueHouse and our various programs and amenities.\n\nWe are looking for new team members who can demonstrate th ...
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSCKieZe6by2yOPf_XqLRObESVKjjQqnFlsxvs&s=0',
#    'extensions': ['6 days ago',
#     '18 an hour',
#     'Full-time',
#     'No degree mentioned'],
#    'detected_extensions': {'posted_at': '6 days ago',
#     'schedule_type': 'Full-time',
#     'salary': '18 an hour'},
#    'job_id': '...'},
#   {'title': 'East One Coffee Roasters is Hiring Baristas!',
#    'company_name': 'East One Coffee Roasters',
#    'location': 'Brooklyn, NY (+1 other)',
#    'via': 'via New York Coffee Jobs',
#    'description': 'About us: East One Coffee Roasters is a coffee-obsessed, diverse, hospitality-based team. We want you to feel welcome at our table every time you visit or work with us. Through…',
#    'extensions': ['25 days ago', 'Full-time', 'No degree mentioned'],
#    'detected_extensions': {'posted_at': '25 days ago',
#     'schedule_type': 'Full-time'},
#    'job_id': '...'},
#   {'title': 'Barista',
#    'company_name': 'Friedmans',
#    'location': 'New York, NY (+1 other)',
#    'via': 'via Seasoned',
#    'description': "As the barista, you will skillfully craft the perfect beverage with consistency. With a wide range of beverage offerings, attention to detail and working quickly & accurately will help ensure your success. You'll also be responsible for keeping your station and the larger establishment clean and stocked. Being a barista offers you a community of passionate coffee lovers and frequent opportunities for continued learning.",
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyTYfy0-8zhbU7yYmJ7HTsL4ZR5Oj4l22p33qx&s=0',
#    'extensions': ['16 days ago', 'Full-time', 'No degree mentioned'],
#    'detected_extensions': {'posted_at': '16 days ago',
#     'schedule_type': 'Full-time'},
#    'job_id': '...'},
#   {'title': 'Barista',
#    'company_name': 'Company Culture',
#    'location': 'New York, NY (+1 other)',
#    'via': 'via Culinary Agents',
#    'description': "Located between Grand Central Terminal and Bryant Park, Company Culture is a specialty coffee shop within The Company Building. The space was designed for guests to sit down and enjoy their coffee. We serve Counter Culture, using Modbar equipment, made by skilled and thoughtful baristas.\n\nIdeal Candidates...\n- Love coffee\n- Are early risers\n- Have genuine interest in coffee trends and culture\n- Respect and follow proper coffee techniques\n- Enjoy delivering warm hospitality and friendly service\n- Are interested in fostering a community within a community\n\nWe're hiring a coffee manager and baristas to join our opening. Ideal candidates thrive in a team environment with excellent collaboration and communication skills. Each member should feel confident and comfortable sharing their coffee knowledge with curiosity for continued education. It is also everyone's responsibility to make guests feel welcome and well taken care of.\n\nCompany is the first vertical, multi-tenant tech campus at... scale in New York. Company curates a collection of startups, entrepreneurs, and enterprises working towards the realization of impactful ideas, together. We offer tenants and members an unparalleled experience by bridging purpose-built spaces, human hospitality, and technology to create a more joyful workplace",
#    'extensions': ['7 days ago', 'Full-time'],
#    'detected_extensions': {'posted_at': '7 days ago',
#     'schedule_type': 'Full-time'},
#    'job_id': '...'},
#   {'title': 'Barista',
#    'company_name': 'Solid State Coffee',
#    'location': 'New York, NY (+1 other)',
#    'via': 'via Good Food Jobs.',
#    'description': "As we slowly creep out of the darkness of the COVID-19 pandemic, we see an opportunity to grow our team with someone who shares our values of great service, great coffee and a commitment to a platform that strives for sustainability and inclusivity.\n\nAs a barista at our busy and evolving cafe, you are tasked with serving our coffees with an eye for quality of both coffee and service. We want to create an environment for our guests that is both new and exciting as well as warm and familiar. This means an ideal candidate isn’t necessarily a World Barista Champion (though if you're out there, that’d be great, please do apply!), but rather a kind, caring individual who understands our mission and wants to grow their knowledge and experience in the coffee world.\n\nOther ideal qualities include:\n• Some experience in specialty coffee or related service industry\n• NYC Food Handler’s permit\n• Open availability including at least one weekend day\n• Willingness and desire to learn!",
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2ZVmDQTo1D2HsXvtAxXU6ryzlddm_K_SZb7qE&s=0',
#    'extensions': ['Over 1 month ago', 'Full-time', 'No degree mentioned'],
#    'detected_extensions': {'posted_at': 'Over 1 month ago',
#     'schedule_type': 'Full-time'},
#    'job_id': '...'},
#   {'title': 'Barista',
#    'company_name': 'Starbucks',
#    'location': 'New York, NY',
#    'via': 'via Snagajob',
#    'description': "Job Description\n\nBENEFITS\n\nBenefits-eligible partners (employees working 20 or more hours a week) can get a wide range of perks, benefits and assistance.\n\nOne of the amazing benefits is the Starbucks College Achievement Program (SCAP):\n\nIn a first of its kind collaboration with Arizona State University, we’re offering all part- and full-time benefits eligible U.S. partners full tuition coverage to earn a bachelor’s degree. Partners receive support from a dedicated team of coaches and advisors, 24/7 tutoring on a variety of subjects, and a choice of more than 70 undergraduate degrees through ASU's research driven and top-ranked program, delivered online.\n\nThe Starbucks College Achievement Plan is just one way we’re committed to the success of our partners. From growing as a person, as a partner, in your career and in your community – the opportunity is here for you to shape and make your own.\n\nJOB DESCRIPTION: BARISTA\n\nResponsibilities and essential job functions include but are not... limited to the following:\n• Acts with integrity, honesty and knowledge that promote the culture, values and mission of Starbucks.\n• Maintains a calm demeanor during periods of high volume or unusual events to keep store operating to standard and to set a positive example for the shift team.\n• Anticipates customer and store needs by constantly evaluating environment and customers for cues.\n• Communicates information to manager so that the team can respond as necessary to create the Third Place environment during each shift.\n• Assists with new partner training by positively reinforcing successful performance and giving respectful and encouraging coaching as needed.\n• Contributes to positive team environment by recognizing alarms or changes in partner morale and performance and communicating them to the store manager.\n• Delivers legendary customer service to all customers by acting with a customer comes first attitude and connecting with the customer. Discovers and responds to customer needs.\n• Follows Starbucks operational policies and procedures, including those for cash handling and safety and security, to ensure the safety of all partners during each shift.\n• Maintains a clean and organized workspace so that partners can locate resources and product as needed.\n• Provides quality beverages, whole bean, and food products consistently for all customers by adhering to all recipe and presentation standards. Follows health, safety and sanitation guidelines for all products.\n• Recognizes and reinforces individual and team accomplishments by using existing organizational methods.\n• Maintains regular and punctual attendance\n\nJob will be at your nearest Starbucks location\n\nSKILLS\n• Ability to learn quickly\n• Ability to understand and carry out oral and written instructions and request clarification when needed\n• Strong interpersonal skills\n• Ability to work as part of a team\n• Ability to build relationships\n\nQUALIFICATIONS\n\nNo previous experience required.\n• Maintain regular and consistent attendance and punctuality, with or without reasonable accommodation\n• Available to work flexible hours that may include early mornings, evenings, weekends, nights and/or holidays\n• Meet store operating policies and standards, including providing quality beverages and food products, cash handling and store safety and security, with or without reasonable accommodation\n• Engage with and understand our customers, including discovering and responding to customer needs through clear and pleasant communication\n• Comply with a dress code that prohibits displaying tattoos, piercings in excess of two per ear, and unnatural hair colors, such as blue or pink\n• Prepare food and beverages to standard recipes or customized for customers, including recipe changes such as temperature, quantity of ingredients or substituted ingredients\n• Available to perform many different tasks within the store during each shift\n\nABOUT  ...
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRwIa6_cB3U7-Xy7sTnFhiYifS4ZlrnXnfqjWBI&s=0',
#    'extensions': ['10 days ago', 'Full-time'],
#    'detected_extensions': {'posted_at': '10 days ago',
#     'schedule_type': 'Full-time'},
#    'job_id': '...'},
#   {'title': 'Barista',
#    'company_name': 'La Bergamote',
#    'location': 'New York, NY (+1 other)',
#    'via': 'via ZipRecruiter',
#    'description': 'Job Description\n\nThe candidates will need experience in the food industry as well as mastering american and europeen coffees, have a positive attitude while working in a rushed environment, have its station clean and a flexible schedule!',
#    'extensions': ['Over 1 month ago', 'Part-time'],
#    'detected_extensions': {'posted_at': 'Over 1 month ago',
#     'schedule_type': 'Part-time'},
#    'job_id': '...'},
#   {'title': 'Barista',
#    'company_name': 'RH',
#    'location': 'New York, NY',
#    'via': 'via LinkedIn',
#    'description': 'Job Description\n\nRH at its core is about taste, and we believe the idea of scaling taste is large and far reaching.\n\nThe RH brand attracts the best designers, artisans, manufacturers and talent in our industry, scaling and rendering their work more valuable across our integrated platform, enabling us to curate the most compelling collection of luxury home furnishings in the world. We are moving the brand beyond curating and selling products to conceptualizing and selling spaces by building an ecosystem of products, places, services and spaces that elevates and establishes the RH brand as a global thought leader, taste and place maker.\n\nAt RH we believe deeply that the "right" people are our greatest asset. We value people with high energy, who possess the ability to energize others. People who are smart, creative and have a point of view. People who see the answer in every problem, versus those who see the problem in every answer. People who are driven, determined and won\'t take "no... for an answer. We value team players, people who are more concerned with what\'s right, rather than who\'s right.\n\nRH is seeking a Barista to join our team in providing world-class service to guests while taking great care of our equipment and facilities.\n\nResponsibilities\n• Live Our Vision, Values and Beliefs every day\n• Responsible for the daily setup and breakdown of the barista bar\n• Provide perfectly poured coffee, tea, alcoholic, and non-alcoholic beverages on the menu\n• Run food and beverages to tables, interacting with guests to ensure they feel welcomed\n• Learn all food and beverage offerings, including: ingredients, methods of preparation and proper service; explain all food and beverage items listed on the menu\n• Answer guest questions with regards to the property, and connect guests with appropriate RH associates to assist with other services\n• Participate in teamwork and foster harmonious working climate\n\nRequirements\n• 2+ years experience as a Server with fundamental food and wine knowledge\n• Proper alcohol and food certifications specific to State Laws\n• Must be of legal age per state law to serve alcohol\n• Willingness to work a flexible schedule, including weekends and holidays\n• Experience with Micros or a similar POS system\n• Knowledgeable of coffee program\n\nPhysical Requirements\n• Must be able to lift up to 50 pounds\n• Must be able to work standing and walking for extended periods of time\n\nAbout Us\n\nRH is an equal opportunity employer and does not discriminate against any applicant on the basis of race, color, religion, national origin, gender, marital status, age, disability, sexual orientation, military/veteran status, or any other status protected by federal or state law or local ordinance',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTQg09ipLaH80GSaQ7E9c2tXZO_X8uqRriW8fZX&s=0',
#    'extensions': ['10 hours ago', 'Part-time', 'No degree mentioned'],
#    'detected_extensions': {'posted_at': '10 hours ago',
#     'schedule_type': 'Part-time'},
#    'job_id': '...'}],
#  'chips': [{'type': 'Title',
#    'param': 'job_family_1',
#    'options': [{'text': ".WGYX8{box-sizing:border-box;background:#fff;border:1px solid #dadce0;border-radius:18px;color:#3c4043;cursor:pointer;display:inline-block;font:400 12px Roboto,arial,sans-serif;height:36px;min-width:36px;position:relative}.WGYX8:after{bottom:-7px;content:'';left:-1px;position:absolute;right:-1px;top:-7px}.WGYX8:hover{background:#f8f9fa}.KymMLe:focus .WGYX8,a:focus .WGYX8,.WGYX8:focus{background:#f8f9fa;border-color:#9aa0a6;color:#e8eaed}.KymMLe:focus .WGYX8:hover:not(:active),a:focus .WGYX8:hover:not(:active),.WGYX8:hover:focus:not(:active){background:#dadce0;border-color:#9aa0a6}.WGYX8:hover,.KymMLe:focus .WGYX8,a:focus .WGYX8,.KymMLe:active .WGYX8,a:active .WGYX8,.WGYX8:focus,.WGYX8:active{color:#202124}.KymMLe:active .WGYX8:not([disabled]),a:active .WGYX8:not([disabled]),.WGYX8:active:not([disabled]){box-shadow:0 1px 2px rgba(60,64,67,.3), 0 2px 6px 2px rgba(60,64,67,.15);border-color:transparent;background:#fff}.WGYX8[disabled]{background:#f1f3f4;border-color:#f1f3f4;color:#bdc1c6;opacity:0.38}.WGYX8[selected]{background:#e8f0fe;border-color:#d2e3fc;color:#1967d2}.zAoYTe .WGYX8[selected]:not(:focus),html:not(.zAoYTe) .WGYX8[selected]{outline:1px solid transparent}.KymMLe:focus .WGYX8[selected],a:focus .WGYX8[selected],.WGYX8[selected]:focus{border-color:#8ab4f8;color:#174ea6;background:#d2e3fc}.KymMLe:active .WGYX8[selected],a:active .WGYX8[selected],.WGYX8[selected]:active{box-shadow:0 1px 2px rgba(66,133,244,.3), 0 1px 3px 1px rgba(66,133,244,.15);background:#e8f0fe;color:#174ea6}.WGYX8[selected]:hover{background:#d2e3fc;border-color:#d2e3fc;color:#174ea6}.KymMLe:focus .WGYX8[selected]:hover:not(:active),a:focus .WGYX8[selected]:hover:not(:active),.WGYX8[selected]:hover:focus:not(:active){background:#aecbfa;border-color:#d2e3fc}.AB4Jjf{font-size:14px;line-height:34px;padding:0 8px;text-align:center}.AB4Jjf,.qfpP8d,.ktgKbb{box-sizing:border-box;display:inline-block;height:34px;vertical-align:bottom}.AB4Jjf.gLDgs{min-width:46px;padding:0 11px}All",
#      'value': None},
#     {'text': 'Barista', 'value': 'barista'},
#     {'text': 'Starbucks barista', 'value': 'starbucks barista'},
#     {'text': 'Person', 'value': 'person'},
#     {'text': 'Certification', 'value': 'certification'},
#     {'text': 'Cook', 'value': 'cook'},
#     {'text': 'Counter person', 'value': 'counter person'},
#     {'text': 'Server', 'value': 'server'},
#     {'text': 'Team member', 'value': 'team member'}]},
#   {'type': 'Location',
#    'param': 'city',
#    'options': [{'text': 'All', 'value': None},
#     {'text': 'New York, NY', 'value': 'Owg_06VPwoli_nfhBo8LyA=='},
#     {'text': 'Long Beach, NY', 'value': 'yYQBQ_ZvwoljkDvjoW2T0w=='},
#     {'text': 'Bronxville, NY', 'value': 'J0ZDIKWSwolhVb6ehTpKYw=='},
#     {'text': 'Garden City, NY', 'value': 'xUU-IzV9womZ1QVzSHrgDg=='},
#     {'text': 'Nanuet, NY', 'value': 'MW8r0BLowonO5FzJCKUB8w=='},
#     {'text': 'Rye, NY', 'value': 'qc-LP9GQwomQZ14eXOixnA=='},
#     {'text': 'Tuckahoe, NY', 'value': 'VdAwOcGSwom67D0TQXMtEw=='},
#     {'text': 'West Nyack, NY', 'value': 'vzIgVzbowom-MeUdAm6dcg=='},
#     {'text': 'Albertson, NY', 'value': 'N0plyt6HwomvQ0G_LAGswQ=='},
#     {'text': 'Ardsley, NY', 'value': 'X2YBWKqUwomdFLoW-xr0ig=='},
#     {'text': 'Armonk, NY', 'value': 'd6-xgGi8wokXuqQOjd3JFA=='},
#     {'text': 'Atlantic Beach, NY', 'value': 'nwsRyERvwom0mXSy5emX1A=='},
#     {'text': 'Bellerose, NY', 'value': 'DSoty0ZiwolrGWosVK7UOg=='},
#     {'text': 'Greenvale, NY', 'value': 'J6FzXROGwokKTVapLXZvgg=='},
#     {'text': 'Hartsdale, NY', 'value': 'xbmw1pCUwokKnBrb6mt0qA=='},
#     {'text': 'Hastings-on-Hudson, NY', 'value': 'c_9lkenswonDC3-VRD5oKQ=='},
#     {'text': 'Hicksville, NY', 'value': 'u3lvHeKAwomU2kg0LrOA5A=='},
#     {'text': 'Irvington, NY', 'value': 'xSxJ-jzrwonVOP6gaEDiHw=='},
#     {'text': 'Lawrence, NY', 'value': 'iYi_UY5lwonoDyc2yCtcQA=='},
#     {'text': 'New City, NY', 'value': 'FZyVPQDDwonwIFXZcYIVBw=='},
#     {'text': 'New Hyde Park, NY', 'value': 'OfwQ1pJiwolAhmseIHElsA=='},
#     {'text': 'Uniondale, NY', 'value': 'L5EGUrB9wokJzAopkN4Dwg=='},
#     {'text': 'White Plains, NY', 'value': '2TWj4iKUwols_FsaEAQUVA=='},
#     {'text': 'Williston Park, NY', 'value': 'aTcdY-SHwokPI6VFey0www=='},
#     {'text': 'Yonkers, NY', 'value': 'oa9DCQjAwomi2tikhHOWvg=='},
#     {'text': 'ARDSLEY HDSN, NY', 'value': 'AAAAAAAAAAAAAAAAAAAAAA=='},
#     {'text': 'Arden, NY', 'value': 'a51WM8HZwokIIHM3zRpf0w=='},
#     {'text': 'Baldwin, NY', 'value': 'mZxjZIR7wom_Zon5y5xiFw=='},
#     {'text': 'Bellmore, NY', 'value': 'Ax4VKCl5wonSgDT3GxnAHA=='},
#     {'text': 'Berkeley Heights, NJ', 'value': 'j1YfgL26w4miHFQ6F1eRKQ=='},
#     {'text': 'Carle Place, NY', 'value': 'hXEFTYOHwolc8QmCc_WerA=='},
#     {'text': 'Cedarhurst, NY', 'value': 'hRc328ZlwonhXsREt2MLYQ=='},
#     {'text': 'Clifton, NJ', 'value': '6drDvuL-wolTMn8iM1gZZA=='},
#     {'text': 'Closter, NJ', 'value': '83-F_TzuwolwAArRIA3YWw=='},
#     {'text': 'Dobbs Ferry, NY', 'value': '20Y_Ip7swom9uR3rK9UaEA=='},
#     {'text': 'East Meadow, NY', 'value': 'xRyHMgh-wokSKBTPpQZ8aw=='},
#     {'text': 'East Norwich, NY', 'value': 'fW1W8qCDwon7X7UAPULOAg=='},
#     {'text': 'Eastchester, NY', 'value': '1YOoSOWSwolAv4tUJPbePA=='},
#     {'text': 'Edgewater, NJ', 'value': 'k4UqK072wontnGQgQuMoTw=='},
#     {'text': 'Edison, NJ', 'value': 'maG-aH_Tw4nq1INvpsUr8g=='},
#     {'text': 'Elmont, NY', 'value': 'ReHg1QRjwolxNPZXDROsDA=='},
#     {'text': 'Elmsford, NY', 'value': 'G9RGDxmVwoktOUKJXYAJXQ=='},
#     {'text': 'Englewood Cliffs, NJ', 'value': 'Fw0eHkPxwon8GIPyu8YylA=='},
#     {'text': 'Englewood, NJ', 'value': 'jXk9hxjxwom-mx-eaJrGxA=='},
#     {'text': 'Farmingdale, NY', 'value': 'HzVsCLwq6Il7xE8IEuknFQ=='},
#     {'text': 'Franklin Square, NY', 'value': 'IYqh5iFjwongahMn5I4GMg=='},
#     {'text': 'Freeport, NY', 'value': '1esxKIZ7wokVOR48olu3hQ=='},
#     {'text': 'Glen Cove, NY', 'value': 'z_V_bxGFwon84T6o2QYuTQ=='},
#     {'text': 'Glen Head, NY', 'value': 'GaCjboqDwomNuf-bbdG6mA=='},
#     {'text': 'Glenwood Landing, NY', 'value': 'S4pChOOFwolZRZdOvLiROQ=='},
#     {'text': 'Great Neck, NY', 'value': 'XQNBzXCJwom4QdhfOY3vcQ=='},
#     {'text': 'Greenwood Lake, NY', 'value': 'P-EStUchw4lCrGkjgfVqUw=='},
#     {'text': 'Harrison, NY', 'value': 'RXu0a-mWwomMlCbJwnxsVA=='}]},
#   {'type': 'Date posted',
#    'param': 'date_posted',
#    'options': [{'text': 'All', 'value': None},
#     {'text': 'Past day', 'value': 'today'},
#     {'text': 'Past 3 days', 'value': '3days'},
#     {'text': 'Past week', 'value': 'week'},
#     {'text': 'Past month', 'value': 'month'}]},
#   {'type': 'Requirements.pXCzbb{border-left:6px solid transparent;border-right:6px solid transparent;height:0;width:0}.f5QV0d{border-bottom:6px solid #1a73e8;margin-top:-41px}.X1JR3{border-top:6px solid #1a73e8}.fggD7{margin-left:27px}.ifeRGc{right:16px;position:absolute}.mrGaL{left:16px;position:absolute}.xIBC4e{background-color:#1a73e8;border-radius:8px;color:#fff;display:inline-block;font:14px Roboto-medium,arial,sans-serif-medium,sans-serif;line-height:20px;padding:8px 12px}.XBFdTb{position:absolute;z-index:80}.SPJsgc{margin-left:184px;margin-right:8px;margin-top:52px;-webkit-transition:opacity 500ms}.otfdK{right:15px;top:47px;-webkit-transition:opacity 500ms}.jxqSg{right:15px;top:-44px;-webkit-transition:opacity 500ms}.OZzQ9b{left:-16px;top:14px;-webkit-transition:opacity 500ms}New! Find jobs based on education or experience requirements',
#    'param': 'requirements',
#    'options': [{'text': 'All', 'value': None},
#     {'text': 'No degree', 'value': 'no_degree'},
#     {'text': 'No experience', 'value': 'no_experience'},
#     {'text': 'Under 3 years of experience', 'value': 'years3under'},
#     {'text': '3+ years of experience', 'value': 'years3plus'}]},
#   {'type': 'Type',
#    'param': 'employment_type',
#    'options': [{'text': 'All', 'value': None},
#     {'text': 'Full-time', 'value': 'FULLTIME'},
#     {'text': 'Part-time', 'value': 'PARTTIME'},
#     {'text': 'Contractor', 'value': 'CONTRACTOR'},
#     {'text': 'Internship', 'value': 'INTERN'}]},
#   {'type': 'Company type',
#    'param': 'industry.id',
#    'options': [{'text': 'All', 'value': None},
#     {'text': 'Foods & Beverages', 'value': '/business/naics2007/311'},
#     {'text': 'Restaurant', 'value': '/business/naics2007/722'},
#     {'text': 'Retail', 'value': '/business/naics2007/44'},
#     {'text': 'Accommodation', 'value': '/business/naics2007/721'},
#     {'text': 'Textiles & Apparel', 'value': '/business/naics2007/313'},
#     {'text': 'Engineering Services', 'value': '/business/naics2007/5413'},
#     {'text': 'Health Care', 'value': '/business/naics2007/62'},
#     {'text': 'Manufacturing', 'value': '/business/naics2007/31'},
#     {'text': 'Real Estate', 'value': '/business/naics2007/53'},
#     {'text': 'Toiletries', 'value': '/business/naics2007/3256'}]},
#   {'type': 'Employer',
#    'param': 'organization_mid',
#    'options': [{'text': 'All', 'value': None},
#     {'text': 'Starbucks', 'value': '/m/018c_r'},
#     {'text': 'HMSHost', 'value': '/m/07b72m'},
#     {'text': 'Flex by Jitjatjo', 'value': '/g/11c73vhkp1'},
#     {'text': "Macy's", 'value': '/m/01pkxd'},
#     {'text': 'The Cheesecake Factory', 'value': '/m/04n2g7'},
#     {'text': 'Bluestone Lane', 'value': '/g/11h6ys2kng'},
#     {'text': 'Barnes & Noble', 'value': '/m/01b7dt'},
#     {'text': 'Aramark', 'value': '/m/02twx1'},
#     {'text': 'Blue Bottle Coffee', 'value': '/m/03p12qd'},
#     {'text': 'Compass Group', 'value': '/g/11ckkxnnp3'},
#     {'text': 'Compass Group, North America', 'value': '/g/11bc6ld96b'},
#     {'text': 'Ralph Lauren', 'value': '/m/04lg33'},
#     {'text': 'Restaurant Associates', 'value': '/g/11dxq2tnnv'},
#     {'text': 'Cafe Grumpy', 'value': '/g/11b7c7x35l'},
#     {'text': 'Chartwells Higher Education', 'value': '/g/11g7z03l8v'},
#     {'text': 'Dartcor Food Services', 'value': '/g/11dxpj2k6d'},
#     {'text': 'Davidson Hotels and Resorts', 'value': '/g/11c73k8cmf'},
#     {'text': 'Delaware North', 'value': '/m/04xvsq'},
#     {'text': 'Dr Smood Group', 'value': '/g/11dxpvcs3m'},
#     {'text': 'Elior North America', 'value': '/g/11fy1vg90w'},
#     {'text': 'Highgate Hotels', 'value': '/g/11k6tcl93y'},
#     {'text': "Hudson's Bay Company", 'value': '/m/03gqj'},
#     {'text': 'Irving Farm Coffee Roasters', 'value': '/g/11b7crh48x'},
#     {'text': 'Joe Coffee Company', 'value': '/g/11b7cfjgxv'},
#     {'text': 'Juice Press', 'value': '/g/11cs465sqc'}]}]}

# %%
jobs_results = results['jobs_results']
jobs_results
# Out:
# [{'title': 'Barista',
#   'company_name': 'Blue Bottle Coffee',
#   'location': 'New York, NY',
#   'via': 'via ZipRecruiter',
#   'description': 'Blue Bottle Coffee is a passionate and growing team of hundreds around the world, united by the simple purpose of connecting the world to delicious coffee. We roast on four coasts, make delicious drinks, clean up after ourselves, bake cookies, get change at the bank, and say please and thank you. We\'re an impossibly eclectic group of coffee experts, artists, writers, sensory scientists, bakers, designers, and all-around dreamers, who also happen to be some of the most hard-working and talented in the business. Join us.\n\nWe\'re looking for unabashed coffee and food lovers to join our crew at our cafes. The ideal barista is someone who is passionate about coffee, food and creating incredible guest experiences grounded in respect, empathy, and recognition. Don\'t have prior coffee, food or service experience? Don\'t sweat it; though that helps, it\'s not all we\'re looking for. We\'re more interested in who you are and what you care about. The whole "what" and "how" thing comes later, and with... plenty of practice.\n\nThis is a career opportunity, nonseasonal role.\nYou will:\n• Deliver impeccable hospitality to our guests and your fellow teammates\n• Work in a team to \'dial in\' and serve a selection of delicious coffees in a variety of different brewing methods including but not limited to: espresso, pour over, and cold brew\n• Expedite and serve delicious sweet and savory food created by our talented culinary team - this can include assembly, delivery and clearing of these treats\n• Stay knowledgeable about Blue Bottle\'s current coffee and food offerings through tastings, cuppings and information provided to you by your Lead Barista, Cafe Leader, the Training and Culinary Departments, and others at Blue Bottle\n• Drink your and others\' coffee and espresso drinks regularly at Blue Bottle cafes to ensure quality, uphold our standards, and keep developing your coffee palate\n• Support your team in keeping the cafe running smoothly and beautifully - these tasks may vary but can include washing dishes, clearing dishes, sweeping, dusting, mopping, cleaning and organizing condiment station, and taking out trash\n\nYou are:\n• Searching for at least 1 year of employment and a nonseasonal opportunity\n• Passionate about coffee, food and creating hospitality experiences\n• A professional - you are serious about your work but don\'t take yourself too seriously\n• Reliable and consistent - your manager and teammates can always depend on you to be punctual, looking sharp in accordance with our dress code, and bringing your A game\n• Obsessed with the details! You love honing your craft and understand each cup of coffee and each plate of delicious food for its individual potential\n• Dedicated to your team and your guests - you understand and value empathy and use it to guide interactions on and off the job\n• Eligible to work in the United States and 18 years of age or older\n\nYou have:\n• Existing Food Handler\'s Certification or certification within 30 days post-hire for the state you will be working in\n• Basic math and computer skills\n• A flexible schedule and are available to work weekends\n\nOur barista position is a dynamic one! Below we\'ve mapped out the physical demands that are essential to the role:\n• Ability to stand and walk for long periods of time. You\'re on your feet the majority of the day, whether you are standing behind bar pulling shots or walking the cafe floor\n• Use of hands to reach, grip, turn and perform precision work. You\'re using your hands to operate beautiful espresso machines, pour delicious pour overs, and operate the register (among other responsibilities)\n• As needed squat, bend, twist and reach for items below waist level or above shoulders. For example, you may have to bend down or reach up to grab cups, lids and towels\n• Ability to lift, push/pull, carry and/or move up to 50 pounds. For example, you\'ll be handling bags of coffee beans, coffee kegs, crates of milk, tub  ...
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR5tE_D3p4jQG3SyoJL5ZqU1UJXO5WkNdfV0Bxd&s=0',
#   'extensions': ['Over 1 month ago', 'Full-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': 'Over 1 month ago',
#    'schedule_type': 'Full-time'},
#   'job_id': '...'},
#  {'title': 'Barista',
#   'company_name': 'Irving Farm Coffee Roasters',
#   'location': 'New York, NY (+1 other)',
#   'via': 'via Good Food Jobs.',
#   'description': 'JOB DESCRIPTION\n\nBaristas are responsible for running the bar to Irving Farm New York standards and delivering outstanding customer service. Our baristas will develop a thorough knowledge of our coffees and maintain quality in all offerings. Irving Farm is an Equal Employment Opportunity Employer. We strongly encourage applicants of all races, ethnicities, genders, and sexual orientations to apply; we are committed to a diverse workplace and world.\n\nREQUIREMENTS\n• Candidates must have open availability and a willingness to work irregular hours, including nights and weekends\n• At least 12 months experience as barista preferred, preferably at a high volume café\n• Outstanding customer service skills\n• Preference will be given to those with a NYS Food Handler’s license; obtaining a license within 30 days of hire will be a requirement of the position\n• Ability to work with others\n• Detail oriented\n• Ability to lift, push and pull up to 50 lbs\n• Must be able to stand for long periods of... time\n\nGENERAL RESPONSIBILITIES:\n• Practice proper cleaning and preventative maintenance for espresso and brewing equipment\n• Be knowledgeable about new coffee offerings and participate in tastings of new coffees\n• Follow Irving Farm standards for opening and closing procedures\n• Uphold and maintain the standards of Irving Farm New York\n• Make drinks in a consistent manner\n• Provide service in a fun, friendly and efficient way\n• Maintain a clean and functioning bar\n• Happily assist staff from other departments when requested and where able\n• Stay informed and educated on industry trends and developments\n• Register and Customer Service\n\nBENEFITS:\n• Competitive hourly pay rate\n• Opportunities to participate in company health insurance after 90 days of employment at 50% employer contribution\n• Opportunity to participate in company 401K plan after 1 year of employment with 4% employer matching\n• Professional Development and Opportunities',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2ZVmDQTo1D2HsXvtAxXU6ryzlddm_K_SZb7qE&s=0',
#   'extensions': ['21 days ago', 'Part-time'],
#   'detected_extensions': {'posted_at': '21 days ago',
#    'schedule_type': 'Part-time'},
#   'job_id': '...'},
#  {'title': 'Barista',
#   'company_name': 'NeueHouse',
#   'location': 'New York, NY (+1 other)',
#   'via': 'via Culinary Agents',
#   'description': "NeueHouse\n\nNeueHouse is the private workspace and cultural home for creators, innovators, and thought leaders. With iconic buildings, timeless design, thought-provoking cultural experiences, and elevated hospitality, NeueHouse has reimagined the ideal environment for creative potential and progress.\n\nOur Properties\n\nNeueHouse currently operates across three different, but equally iconic properties in New York City and Los Angeles:\n• Our Madison Square (MSQ) House is situated in New York’s iconic Flatiron District, was previously home for Tepper Galleries, a well-known Manhattan auction house for international artists and collectors in the 1930s – and neighbors the 69th Regiment Armory where the first International Exhibition of Modern Art was held.\n• Our Hollywood House (HWD), which sits on Sunset Boulevard, is one of LA’s most celebrated buildings and occupies the original CBS Studio (the world’s first structure built intentionally for broadcast). Here genre-defining artists from... Orson Wells and Lucille Ball, to Janis Joplin, the Beach Boys, and Bob Dylan built their legacy.\n• Our Bradbury House (BB) sits within the Bradbury building in DTLA. Built-in 1893, the Bradbury Building is an architectural masterpiece and one of Los Angeles’ most historic landmarks. It has been heralded as one of the most thrilling spaces in all North America and is renowned for its breathtaking skylit atrium filled with walkways, stairs, balconies, and intricate ironwork.\n\nThese properties are complemented by forthcoming houses in Venice Beach, and Miami, as well as proposed European locations. Regardless of locale, and by deliberate design, all our environment and teams support, nurture and connect the NeueHouse community in reaching their creative potential.\n\nThe Role\n\nOur Food & Beverage team is a critical part of creating an outstanding NeueHouse experience and are tasked with sharing the NeueHouse food and drink philosophy with Members and Guests, alike. Baristas on our team create innovative and outstanding food and beverage journeys using our bespoke coffee, drink, and cocktail menus.\n\nBaristas represent NeueHouse in providing hospitality, warmth, and grace with all interactions, supporting, and adding to NeueHouse’s collaborative atmosphere, and making the most of every opportunity to enhance Member and Guest experience. NeueHouse’s team is lean and operates with a mindset of “no task is too small.”\n\nResponsibilities & Requirements\n\nSolution-oriented and taking pride in delivering with details in mind, Baristas build, deliver, and steward the everyday F&B moments defining NeueHouse for Members, Guests, and team. The role requires someone who is ready to:\n• Consistently provide thoughtful and personal service with the goal to develop a rapport with members and guests.\n• Ensure the Café counter and floor are set and ready for service.\n• Maintain the cleanliness and always restock equipment of the Café counter and floor.\n• Maintain thorough working knowledge of menus and be able to articulate to guests in an engaged and thoughtful manner.\n• Proficient use of POS for ordering and billing purposes.\n• Execution of the order of service in a timely and accurate manner with the goal of creating memorable service - we want Members and Guests to remember that cup of coffee!\n• Prepare all food and beverages to the standards of NeueHouse and our partners.\n• Thorough working knowledge of all beverages: coffee/tea/non-alcoholic/wines/beers/spirits.\n• Communicating with prep kitchen to ensure areas are always fully stocked with food and beverage items, alerting the kitchen when running low on a particular item.\n• Develop and coordinate the organization of various areas of The Café and other F&B outlets on property.\n• Competency in conversing with members, guests, and potential members regarding NeueHouse and our various programs and amenities.\n\nWe are looking for new team members who can demonstrate the ...
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSCKieZe6by2yOPf_XqLRObESVKjjQqnFlsxvs&s=0',
#   'extensions': ['6 days ago',
#    '18 an hour',
#    'Full-time',
#    'No degree mentioned'],
#   'detected_extensions': {'posted_at': '6 days ago',
#    'schedule_type': 'Full-time',
#    'salary': '18 an hour'},
#   'job_id': '...'},
#  {'title': 'East One Coffee Roasters is Hiring Baristas!',
#   'company_name': 'East One Coffee Roasters',
#   'location': 'Brooklyn, NY (+1 other)',
#   'via': 'via New York Coffee Jobs',
#   'description': 'About us: East One Coffee Roasters is a coffee-obsessed, diverse, hospitality-based team. We want you to feel welcome at our table every time you visit or work with us. Through…',
#   'extensions': ['25 days ago', 'Full-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': '25 days ago',
#    'schedule_type': 'Full-time'},
#   'job_id': '...'},
#  {'title': 'Barista',
#   'company_name': 'Friedmans',
#   'location': 'New York, NY (+1 other)',
#   'via': 'via Seasoned',
#   'description': "As the barista, you will skillfully craft the perfect beverage with consistency. With a wide range of beverage offerings, attention to detail and working quickly & accurately will help ensure your success. You'll also be responsible for keeping your station and the larger establishment clean and stocked. Being a barista offers you a community of passionate coffee lovers and frequent opportunities for continued learning.",
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyTYfy0-8zhbU7yYmJ7HTsL4ZR5Oj4l22p33qx&s=0',
#   'extensions': ['16 days ago', 'Full-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': '16 days ago',
#    'schedule_type': 'Full-time'},
#   'job_id': '...'},
#  {'title': 'Barista',
#   'company_name': 'Company Culture',
#   'location': 'New York, NY (+1 other)',
#   'via': 'via Culinary Agents',
#   'description': "Located between Grand Central Terminal and Bryant Park, Company Culture is a specialty coffee shop within The Company Building. The space was designed for guests to sit down and enjoy their coffee. We serve Counter Culture, using Modbar equipment, made by skilled and thoughtful baristas.\n\nIdeal Candidates...\n- Love coffee\n- Are early risers\n- Have genuine interest in coffee trends and culture\n- Respect and follow proper coffee techniques\n- Enjoy delivering warm hospitality and friendly service\n- Are interested in fostering a community within a community\n\nWe're hiring a coffee manager and baristas to join our opening. Ideal candidates thrive in a team environment with excellent collaboration and communication skills. Each member should feel confident and comfortable sharing their coffee knowledge with curiosity for continued education. It is also everyone's responsibility to make guests feel welcome and well taken care of.\n\nCompany is the first vertical, multi-tenant tech campus at... scale in New York. Company curates a collection of startups, entrepreneurs, and enterprises working towards the realization of impactful ideas, together. We offer tenants and members an unparalleled experience by bridging purpose-built spaces, human hospitality, and technology to create a more joyful workplace",
#   'extensions': ['7 days ago', 'Full-time'],
#   'detected_extensions': {'posted_at': '7 days ago',
#    'schedule_type': 'Full-time'},
#   'job_id': '...'},
#  {'title': 'Barista',
#   'company_name': 'Solid State Coffee',
#   'location': 'New York, NY (+1 other)',
#   'via': 'via Good Food Jobs.',
#   'description': "As we slowly creep out of the darkness of the COVID-19 pandemic, we see an opportunity to grow our team with someone who shares our values of great service, great coffee and a commitment to a platform that strives for sustainability and inclusivity.\n\nAs a barista at our busy and evolving cafe, you are tasked with serving our coffees with an eye for quality of both coffee and service. We want to create an environment for our guests that is both new and exciting as well as warm and familiar. This means an ideal candidate isn’t necessarily a World Barista Champion (though if you're out there, that’d be great, please do apply!), but rather a kind, caring individual who understands our mission and wants to grow their knowledge and experience in the coffee world.\n\nOther ideal qualities include:\n• Some experience in specialty coffee or related service industry\n• NYC Food Handler’s permit\n• Open availability including at least one weekend day\n• Willingness and desire to learn!",
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2ZVmDQTo1D2HsXvtAxXU6ryzlddm_K_SZb7qE&s=0',
#   'extensions': ['Over 1 month ago', 'Full-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': 'Over 1 month ago',
#    'schedule_type': 'Full-time'},
#   'job_id': '...'},
#  {'title': 'Barista',
#   'company_name': 'Starbucks',
#   'location': 'New York, NY',
#   'via': 'via Snagajob',
#   'description': "Job Description\n\nBENEFITS\n\nBenefits-eligible partners (employees working 20 or more hours a week) can get a wide range of perks, benefits and assistance.\n\nOne of the amazing benefits is the Starbucks College Achievement Program (SCAP):\n\nIn a first of its kind collaboration with Arizona State University, we’re offering all part- and full-time benefits eligible U.S. partners full tuition coverage to earn a bachelor’s degree. Partners receive support from a dedicated team of coaches and advisors, 24/7 tutoring on a variety of subjects, and a choice of more than 70 undergraduate degrees through ASU's research driven and top-ranked program, delivered online.\n\nThe Starbucks College Achievement Plan is just one way we’re committed to the success of our partners. From growing as a person, as a partner, in your career and in your community – the opportunity is here for you to shape and make your own.\n\nJOB DESCRIPTION: BARISTA\n\nResponsibilities and essential job functions include but are not... limited to the following:\n• Acts with integrity, honesty and knowledge that promote the culture, values and mission of Starbucks.\n• Maintains a calm demeanor during periods of high volume or unusual events to keep store operating to standard and to set a positive example for the shift team.\n• Anticipates customer and store needs by constantly evaluating environment and customers for cues.\n• Communicates information to manager so that the team can respond as necessary to create the Third Place environment during each shift.\n• Assists with new partner training by positively reinforcing successful performance and giving respectful and encouraging coaching as needed.\n• Contributes to positive team environment by recognizing alarms or changes in partner morale and performance and communicating them to the store manager.\n• Delivers legendary customer service to all customers by acting with a customer comes first attitude and connecting with the customer. Discovers and responds to customer needs.\n• Follows Starbucks operational policies and procedures, including those for cash handling and safety and security, to ensure the safety of all partners during each shift.\n• Maintains a clean and organized workspace so that partners can locate resources and product as needed.\n• Provides quality beverages, whole bean, and food products consistently for all customers by adhering to all recipe and presentation standards. Follows health, safety and sanitation guidelines for all products.\n• Recognizes and reinforces individual and team accomplishments by using existing organizational methods.\n• Maintains regular and punctual attendance\n\nJob will be at your nearest Starbucks location\n\nSKILLS\n• Ability to learn quickly\n• Ability to understand and carry out oral and written instructions and request clarification when needed\n• Strong interpersonal skills\n• Ability to work as part of a team\n• Ability to build relationships\n\nQUALIFICATIONS\n\nNo previous experience required.\n• Maintain regular and consistent attendance and punctuality, with or without reasonable accommodation\n• Available to work flexible hours that may include early mornings, evenings, weekends, nights and/or holidays\n• Meet store operating policies and standards, including providing quality beverages and food products, cash handling and store safety and security, with or without reasonable accommodation\n• Engage with and understand our customers, including discovering and responding to customer needs through clear and pleasant communication\n• Comply with a dress code that prohibits displaying tattoos, piercings in excess of two per ear, and unnatural hair colors, such as blue or pink\n• Prepare food and beverages to standard recipes or customized for customers, including recipe changes such as temperature, quantity of ingredients or substituted ingredients\n• Available to perform many different tasks within the store during each shift\n\nABOUT U ...
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRwIa6_cB3U7-Xy7sTnFhiYifS4ZlrnXnfqjWBI&s=0',
#   'extensions': ['10 days ago', 'Full-time'],
#   'detected_extensions': {'posted_at': '10 days ago',
#    'schedule_type': 'Full-time'},
#   'job_id': '...'},
#  {'title': 'Barista',
#   'company_name': 'La Bergamote',
#   'location': 'New York, NY (+1 other)',
#   'via': 'via ZipRecruiter',
#   'description': 'Job Description\n\nThe candidates will need experience in the food industry as well as mastering american and europeen coffees, have a positive attitude while working in a rushed environment, have its station clean and a flexible schedule!',
#   'extensions': ['Over 1 month ago', 'Part-time'],
#   'detected_extensions': {'posted_at': 'Over 1 month ago',
#    'schedule_type': 'Part-time'},
#   'job_id': '...'},
#  {'title': 'Barista',
#   'company_name': 'RH',
#   'location': 'New York, NY',
#   'via': 'via LinkedIn',
#   'description': 'Job Description\n\nRH at its core is about taste, and we believe the idea of scaling taste is large and far reaching.\n\nThe RH brand attracts the best designers, artisans, manufacturers and talent in our industry, scaling and rendering their work more valuable across our integrated platform, enabling us to curate the most compelling collection of luxury home furnishings in the world. We are moving the brand beyond curating and selling products to conceptualizing and selling spaces by building an ecosystem of products, places, services and spaces that elevates and establishes the RH brand as a global thought leader, taste and place maker.\n\nAt RH we believe deeply that the "right" people are our greatest asset. We value people with high energy, who possess the ability to energize others. People who are smart, creative and have a point of view. People who see the answer in every problem, versus those who see the problem in every answer. People who are driven, determined and won\'t take "no... for an answer. We value team players, people who are more concerned with what\'s right, rather than who\'s right.\n\nRH is seeking a Barista to join our team in providing world-class service to guests while taking great care of our equipment and facilities.\n\nResponsibilities\n• Live Our Vision, Values and Beliefs every day\n• Responsible for the daily setup and breakdown of the barista bar\n• Provide perfectly poured coffee, tea, alcoholic, and non-alcoholic beverages on the menu\n• Run food and beverages to tables, interacting with guests to ensure they feel welcomed\n• Learn all food and beverage offerings, including: ingredients, methods of preparation and proper service; explain all food and beverage items listed on the menu\n• Answer guest questions with regards to the property, and connect guests with appropriate RH associates to assist with other services\n• Participate in teamwork and foster harmonious working climate\n\nRequirements\n• 2+ years experience as a Server with fundamental food and wine knowledge\n• Proper alcohol and food certifications specific to State Laws\n• Must be of legal age per state law to serve alcohol\n• Willingness to work a flexible schedule, including weekends and holidays\n• Experience with Micros or a similar POS system\n• Knowledgeable of coffee program\n\nPhysical Requirements\n• Must be able to lift up to 50 pounds\n• Must be able to work standing and walking for extended periods of time\n\nAbout Us\n\nRH is an equal opportunity employer and does not discriminate against any applicant on the basis of race, color, religion, national origin, gender, marital status, age, disability, sexual orientation, military/veteran status, or any other status protected by federal or state law or local ordinance',
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTQg09ipLaH80GSaQ7E9c2tXZO_X8uqRriW8fZX&s=0',
#   'extensions': ['10 hours ago', 'Part-time', 'No degree mentioned'],
#   'detected_extensions': {'posted_at': '10 hours ago',
#    'schedule_type': 'Part-time'},
#   'job_id': '...'}]

# %%
df = pd.DataFrame(jobs_results)
df
# Out:
#                                           title                 company_name  \
# 0                                       Barista           Blue Bottle Coffee
# 1                                       Barista  Irving Farm Coffee Roasters
# 2                                       Barista                    NeueHouse
# 3  East One Coffee Roasters is Hiring Baristas!     East One Coffee Roasters
# 4                                       Barista                    Friedmans
# 5                                       Barista              Company Culture
# 6                                       Barista           Solid State Coffee
# 7                                       Barista                    Starbucks
# 8                                       Barista                 La Bergamote
# 9                                       Barista                           RH
#
#                   location                       via  \
# 0             New York, NY          via ZipRecruiter
# 1  New York, NY (+1 other)       via Good Food Jobs.
# 2  New York, NY (+1 other)       via Culinary Agents
# 3  Brooklyn, NY (+1 other)  via New York Coffee Jobs
# 4  New York, NY (+1 other)              via Seasoned
# 5  New York, NY (+1 other)       via Culinary Agents
# 6  New York, NY (+1 other)       via Good Food Jobs.
# 7             New York, NY              via Snagajob
# 8  New York, NY (+1 other)          via ZipRecruiter
# 9             New York, NY              via LinkedIn
#
#                                          description  \
# 0  Blue Bottle Coffee is a passionate and growing...
# 1  JOB DESCRIPTION\n\nBaristas are responsible fo...
# 2  NeueHouse\n\nNeueHouse is the private workspac...
# 3  About us: East One Coffee Roasters is a coffee...
# 4  As the barista, you will skillfully craft the ...
# 5  Located between Grand Central Terminal and Bry...
# 6  As we slowly creep out of the darkness of the ...
# 7  Job Description\n\nBENEFITS\n\nBenefits-eligib...
# 8  Job Description\n\nThe candidates will need ex...
# 9  Job Description\n\nRH at its core is about tas...
#
#                                            thumbnail  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3                                                NaN
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5                                                NaN
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8                                                NaN
# 9  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                           extensions  \
# 0  [Over 1 month ago, Full-time, No degree mentio...
# 1                           [21 days ago, Part-time]
# 2  [6 days ago, 18 an hour, Full-time, No degree ...
# 3      [25 days ago, Full-time, No degree mentioned]
# 4      [16 days ago, Full-time, No degree mentioned]
# 5                            [7 days ago, Full-time]
# 6  [Over 1 month ago, Full-time, No degree mentio...
# 7                           [10 days ago, Full-time]
# 8                      [Over 1 month ago, Part-time]
# 9     [10 hours ago, Part-time, No degree mentioned]
#
#                                  detected_extensions  \
# 0  {'posted_at': 'Over 1 month ago', 'schedule_ty...
# 1  {'posted_at': '21 days ago', 'schedule_type': ...
# 2  {'posted_at': '6 days ago', 'schedule_type': '...
# 3  {'posted_at': '25 days ago', 'schedule_type': ...
# 4  {'posted_at': '16 days ago', 'schedule_type': ...
# 5  {'posted_at': '7 days ago', 'schedule_type': '...
# 6  {'posted_at': 'Over 1 month ago', 'schedule_ty...
# 7  {'posted_at': '10 days ago', 'schedule_type': ...
# 8  {'posted_at': 'Over 1 month ago', 'schedule_ty...
# 9  {'posted_at': '10 hours ago', 'schedule_type':...
#
#                                               job_id
# 0  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 1  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 2  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 3  eyJqb2JfdGl0bGUiOiJFYXN0IE9uZSBDb2ZmZWUgUm9hc3...
# 4  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 5  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 6  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 7  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 8  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...
# 9  eyJqb2JfdGl0bGUiOiJCYXJpc3RhIiwiY29tcGFueV9uYW...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                10 non-null     object
#  1   company_name         10 non-null     object
#  2   location             10 non-null     object
#  3   via                  10 non-null     object
#  4   description          10 non-null     object
#  5   thumbnail            7 non-null      object
#  6   extensions           10 non-null     object
#  7   detected_extensions  10 non-null     object
#  8   job_id               10 non-null     object
# dtypes: object(9)
# memory usage: 848.0+ bytes
